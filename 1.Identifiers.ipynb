# %%
first_name = "Anu" # statement
# variable_name  = value
# snake case ---> first_name

# %%
first_name
# Out:
# 'Anu'

# %%
# camel case  ---->  getStudentMarks , calculateAverage
def getFullName(first_name):
    last_name = "Krishnan"
    print(first_name , " ", last_name)

# %%
getFullName("Radha") # function call
# Out:
# Radha   Krishnan

# %%
getFullName("Senthamarai")
# Out:
# Senthamarai   Krishnan

# %%
# pascal case  ----> Employee, SalaryNotInRange
class Lion:
    name = "Simbha"

# %%
Lion.name
# Out:
# 'Simbha'

# %%
name = "Rakesh"

# %%
type(name)
# Out:
# str

# %%
id(name)
# Out:
# 140333966294640

# %%
name = name + " MBBS"

# %%
name
# Out:
# 'Rakesh MBBS'

# %%
mark = 99.2

# %%
type(mark)
# Out:
# float

# %%
age = 21

# %%
type(age)
# Out:
# int

# %% [markdown]
# # rules and Conventions

# %% [raw]
# rule 1 : A-Z or a- z or _ symbol followed by 0 -9 digits
# rule 2 : should not start with digits
# rule 3 : should never make use of ( !@#$%^&*)
# rule 4 : should never  make use of keywords
# rule 5 : case sensitive

# %% [raw]
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
import sys
sys.version
# Out:
# '3.8.16 (default, Dec  7 2022, 01:12:13) \n[GCC 7.5.0]'

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
A = 100

# %%
a = 10

# %%
A
# Out:
# 100

# %%
a
# Out:
# 10

# %%
raining = True

if raining:
  print("Coffee")
else:
  print("Juice")
# Out:
# Coffee

# %% [markdown]
# **Underscore Usage**

# %% [markdown]
# **Access Specifiers**

# %%
first_name = "Rathna"  # public

# %%
__salary = 1234  # private variable

# %%
_project = "Workforce Analyzer" # protected variable

# %%
def getFullName(first_name):
    """
        This function
        provides full name
        for the name passed 
        as argument
           -- doc-string
    """
    last_name = "Krishnan"
    print(first_name , " ", last_name)

# %%
getFullName("Senthamarai")
# Out:
# Senthamarai   Krishnan

# %%
print(getFullName.__doc__)  # python defined special var
# Out:
#         This function
#         provides full name
#         for the name passed
#         as argument
#            -- doc-string

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
print(math.factorial.__doc__)
# Out:
# Find x!.
#
# Raise a ValueError if x is negative or non-integral.

# %%
math.factorial(4)
# Out:
# 24

# %% [markdown]
# # Lines and Indentation

# %%
raining = True
if raining:
    print("Take umbrella")
else:
    print('Go for work')
# Out:
# Take umbrella

# %%
def sayHello():
  print("Hello one and all")

# %%
class Fish:
  name = "Nemo"

# %%
cash = 900
if cash>1000:
    print("fruits")
    print("snacks")
    print("fuel")
    print("shopping")
else:
    print("fuel")
    print("fruits")
    print('recharge')
print("END of if else")
# Out:
# fuel
# fruits
# recharge
# END of if else

# %% [markdown]
# # Multi-Line Statements

# %%
fruits = 200
snacks = 200
fuel = 200
recharge = 1500
shopping = 300
veg = 600
grocery = 2000
house_hold = 4000

expense = fruits + snacks + fuel +recharge + shopping + veg + grocery + house_hold

expense
# Out:
# 9000

# %%
expense = fruits + snacks + fuel + \
recharge + \
shopping + \
veg + \
grocery + \
house_hold

expense
# Out:
# 9000

# %% [markdown]
# # Quotation in Python

# %% [raw]
# any thing with "" considered as a string

# %% [markdown]
# string is sequence of characters

# %%
word = 'word'

# %%
print(word)
# Out:
# word

# %%
sentence = "Live Life !!!"

# %%
print(sentence)
# Out:
# Live Life !!!

# %%
paragraph = """
                A Man who treats a man 
                as a man he is a real man
                
                Humanity is a basic quality for beign human !!!
                """

# %%
print(paragraph)
# Out:
#                 A Man who treats a man
#                 as a man he is a real man
#
#                 Humanity is a basic quality for beign human !!!

# %%
paragraph = '''
                A Man who treats a man 
                as a man he is a real man
                
                Humanity is a basic quality for beign human !!!
                '''

# %%
print(paragraph)
# Out:
#                 A Man who treats a man
#                 as a man he is a real man
#
#                 Humanity is a basic quality for beign human !!!

# %% [markdown]
# # Comments

# %% [markdown]
# # 1 . Single line Comment

# %%
print("Hello , Python !")  # Hello , Python !
# Out:
# Hello , Python !

# %%
#print("single line comment")

# %% [markdown]
# # 2 . Multi line Comment

# %%
def greet(name):
    """
        This function greets
        the person who come in the
        function argument
    """
    print("Hello ",name ," Good Morning !")

# %%
greet("Hiranya")
# Out:
# Hello  Hiranya  Good Morning !

# %%
print(greet.__doc__)
# Out:
#         This function greets
#         the person who come in the
#         function argument

# %%
def sayHello():
  "Hello one and all"
  print("Hello !!!")

# %%
sayHello()
# Out:
# Hello !!!

# %%
print(sayHello.__doc__)
# Out:
# Hello one and all

# %%
def sayHi():
  'Hii'
  print("Hi one and all")

# %%
sayHi()
# Out:
# Hi one and all

# %%
print(sayHi.__doc__)
# Out:
# Hii

# %% [markdown]
# # Multiple Statements on a Single Line

# %%
pencil = 50
unit_price = 5
total_cost = pencil * unit_price
total_cost
# Out:
# 250

# %%
pencil = 50; unit_price = 5; total_cost = pencil * unit_price; total_cost
# Out:
# 250

# %% [markdown]
# # Multiple Statement Groups as Suites

# %%
if True:  # if header
    print("True") # suites
else :   # else header
    print("False") # suites
# Out:
# True

# %% [raw]
# suites --->  code block
