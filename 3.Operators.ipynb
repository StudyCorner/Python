# %%
a = 10 # statement
b = 12
c = a+b 
c
# c = a+b+10
# a,b operends
# + operator
# expression 
  # operands
  # operators
  # literals(vlaues)
# Out:
# 22

# %% [markdown]
# # Arithmetic operator

# %%
a = 9
b = 2

# %%
a+b
# Out:
# 11

# %%
a-b
# Out:
# 7

# %%
a*b
# Out:
# 18

# %%
a**b # a power b
# Out:
# 81

# %%
a/b
# Out:
# 4.5

# %%
a//b # floor division
# Out:
# 4

# %%
a%b
# Out:
# 1

# %%
import math
math.floor(4.9)
# Out:
# 4

# %%
math.ceil(4.1)
# Out:
# 5

# %%
math.factorial(3)
# Out:
# 6

# %% [markdown]
# # Comparative Operator

# %%
a>b # greater
# Out:
# True

# %%
a<b # lesser
# Out:
# False

# %%
a!=b # != not equal to
# Out:
# True

# %%
100==100
# Out:
# True

# %%
x = 10
y = 20
x=y
x
# Out:
# 20

# %%
a==b # == equality
# Out:
# False

# %%
a>=b ## greater or equal
# Out:
# True

# %%
a<=b # lesser or equal
# Out:
# False

# %% [markdown]
# # Logical Operator

# %%
maths = 90
phy = 92
eng = 90
chem = 99
cs = 100

if maths>40 and phy>40 and eng>40 and chem>40 and cs>40:
    print("Cleared")
else:
    print("not cleared")
# Out:
# Cleared

# %%
snacks = input("Enter your : \t")

if snacks == "ice cream" or snacks =="ice cream cake":
    print("Buy it")
else:
    print("Cancel it")
# Out:
# Enter your : 	ice cream
# Buy it

# %%
raining = False

if not raining: print("Go for shopping")
else: print("Coffee")
# Out:
# Go for shopping

# %% [markdown]
# # Identity Operators

# %%
x = 'Jhon'

# %%
type(x)
# Out:
# str

# %%
type(str)
# Out:
# type

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
isinstance(x,str)
# Out:
# True

# %%
isinstance('Jhon',str)
# Out:
# True

# %%
id(x)
# Out:
# 139979902382384

# %%
id('Jhon')
# Out:
# 139979902382384

# %%
y="Jhon"

# %%
id(y)
# Out:
# 139979902382384

# %%
id(x) == id('Jhon')
# Out:
# True

# %%
y = 'Abraham'

# %%
id(y)
# Out:
# 139979902309232

# %%
id('Jhon')
# Out:
# 139979902382384

# %%
x is y
# Out:
# False

# %%
y = 'Jhonny Depp'

# %%
id('Jhonny Depp')
# Out:
# 139979653255280

# %%
x is y
# Out:
# False

# %%
x is not y
# Out:
# True

# %%
id(x) != id(y)
# Out:
# True

# %%
heena = "London"
seema = "London"

heena is seema
# Out:
# True

# %%
id(heena)
# Out:
# 139979652928240

# %%
id('London')
# Out:
# 139979652928240

# %%
id(seema)
# Out:
# 139979652928240

# %%
id(heena) == id(seema)
# Out:
# True

# %%
heena is seema
# Out:
# True

# %%
heena = "Denmark"
heena is seema
# Out:
# False

# %%
id("Denmark")
# Out:
# 139979652902256

# %%
heena is not seema
# Out:
# True

# %%
id(heena) != id(seema)
# Out:
# True

# %% [markdown]
# # Membership

# %%
class_ = ['Ratna','Lohiya','vishnu']

# %%
std = input("Student name : ")
if std in class_: print("Present")
else: print("Absent")
# Out:
# Student name : vishnu
# Present

# %%
'deepti' not in class_
# Out:
# True

# %% [markdown]
# Doubts

# %%
round(51.6)
# Out:
# 52

# %%
round(51.4)
# Out:
# 51

# %%
round(51.5)
# Out:
# 52

# %%
round(51.1)
# Out:
# 51

# %% [markdown]
# Assert statements

# %%
x = 10
assert x==10
x
# Out:
# 10

# %%
x = 10
assert x==100
x
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-67-04e10eb22d0c> in <cell line: 2>()
#       1 x = 10
# ----> 2 assert x==100
#       3 x
#
# AssertionError:

# %% [markdown]
# # Bitwise Operator

# %%
a = 10
b = 2

# %%
a&b
# Out:
# 2

# %%
a|b
# Out:
# 10

# %%
a^b
# Out:
# 8

# %%
fresher = False
exp = True

if fresher^exp:
  print("eligible candidate")
else:
  print("Try next time")
# Out:
# eligible candidate

# %%
# bit wise not
~a
# -(a+1)
# Out:
# -11

# %% [markdown]
# left shift

# %%
a<<b

# a*2 pow of b
# Out:
# 40

# %% [markdown]
# rigth shift

# %%
a>>b

# a / 2 pow of b
# Out:
# 2

# %% [markdown]
# # Assignment

# %%
a = 3

# %%
a = 3
a = a + 3
a
# Out:
# 6

# %%
a = 3
a += 3  # a = a+3
a
# Out:
# 6

# %%
a = 3
a -= 3  # a = a+3
a
# Out:
# 0

# %%
a = 3
a %= 3  # a = a+3
a
# Out:
# 0

# %%
a = 3
a **= 3  # a = a power of 3
a
# Out:
# 27

# %%
a = 10
a <<= 2  # a = a<<2
a
# Out:
# 40

# %%
a = 3
a ^= 4  # a = a^4
a
# Out:
# 7

# %%
# arithmetic , bitwise
