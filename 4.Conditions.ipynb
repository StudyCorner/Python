# %%
test_condition = True

if test_condition:
    print("TC is True")
# Out:
# TC is True

# %%
if True:
    print("TC is True")
# Out:
# TC is True

# %%
a = 9
b = 3
if a>b:
  print("A is greater")
# Out:
# A is greater

# %%
if 1:
    print("TC is True")
# Out:
# TC is True

# %%
test_condition = 60<100

if test_condition:
    print("TC is True")
# Out:
# TC is True

# %%
x = input("Enter X : \t")
print(type(x))
# Out:
# Enter X : 	7
# <class 'str'>

# %%
# simple if

number = int(input("Enter number : \t"))
if number%2==0:
    print("Even")
# Out:
# Enter number : 	3

# %%
# if else

number = int(input("Enter number : \t"))
if number%2==0:
    print("Even")
else:
    print('Odd')
# Out:
# Enter number : 	3
# Odd

# %%
# if elif

number = int(input("Enter number : \t"))
if number%2==0:
    print("Even and divisible by 2")
elif number%3==0:
    print("Divisible by  3")
elif number%7==0:
    print("divisible by 7")
elif number%5==0:
    print("divisible by 5")
else:
    print('not in suggestion')
# Out:
# Enter number : 	30
# Even and divisible by 2

# %%
if True:
  pass
  if False:
    pass
  else:
    pass
else:
  pass

# %%
cash = 100
if cash:
  pass

# %%
movielist = ["Xmen","Avengers","Iron man"]

for movie in movielist:
  if movie =="Xmen":
    pass

# %%
test1 = int(input("Enter Test 1 mark : \t"))
if test1>=50:
    print("Successfully cleared Test I")
    test2 = int(input("Enter Test 2 mark : \t"))
    if test2>=50:
        print("Successfully Cleared Test II")
        avg = (test1 + test2)/2
        if avg>=75:
            print("Short Listed with {} %".format(avg))
        else:
            print('Better luck next time --> {}% Too low '.format(avg))
    else:
        print("Failed to clear Test II ")
else:
    print("Failed to clear Test I ")
# Out:
# Enter Test 1 mark : 	25
# Failed to clear Test I

# %%
num = int(input("Enter number : ")) # 30
if num%5==0:
    print("Divisible by 5")
    if num%2==0:
        print("divisible by 10")
        if num%6==0:
            print("divisible by 6")
            if num%3==0:
                print("divisible by 3")
# Out:
# Enter number : 30
# Divisible by 5
# divisible by 10
# divisible by 6
# divisible by 3

# %%
if False:
  pass
else:
  print("bye")
# Out:
# bye

# %%
cash = 500
if cash in range(501):
    fruits = 100
    cash = cash-fruits
    print("bought fruits for 100  ramiang ",cash)
    if cash in range(401):
        veg = 100
        cash= cash-veg
        print("bought veggis for 100  ramiang ",cash)
    if cash in range(301):
        biscuts = 50
        cash = cash-biscuts
        print("bought bicsuits  ramiang ",cash)
    if cash in range(390):
        choclates = 100
        cash = cash-choclates
        print("bought choclates remaining ",cash)
        if  cash in range(100):
            print("Stay at home")
        else:
            print("shop again")
# Out:
# bought fruits for 100  ramiang  400
# bought veggis for 100  ramiang  300
# bought bicsuits  ramiang  250
# bought choclates remaining  150
# shop again

# %%
-3 in range(5,-5,-1)
# 5,4,3,2,1,0,-1,-2,-3,-4
# Out:
# True

# %%
x=range(0,11,2)
x
# 1,3,5,7,9
# 0,2,4,6,8,10
# Out:
# range(0, 11, 2)

# %%
6 in x
# Out:
# True

# %%
30 in range(1,6)
# Out:
# False

# %%
500 in range(200,501)
# Out:
# True

# %%
x = range(100)
type(x)
# Out:
# range

# %%
type(range)
# Out:
# type

# %%
help(range)
# Out:
# Help on class range in module builtins:
#
# class range(object)
#  |  range(stop) -> range object
#  |  range(start, stop[, step]) -> range object
#  |
#  |  Return an object that produces a sequence of integers from start (inclusive)
#  |  to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
#  |  start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
#  |  These are exactly the valid indices for a list of 4 elements.
#  |  When step is given, it specifies the increment (or decrement).
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __gt__(self, value, /)
# ...

# %%
x = range(1,11,1)
x
# Out:
# range(1, 11)

# %%
y = range(6)
y
# Out:
# range(0, 6)

# %%
x = 10
y = 20

if x ==10:
    print("Ten")
    if y == 20:
        print("Twenty")
# Out:
# Ten
# Twenty

# %%
# short hand if
# ternary operator or conditional expressions

if 6>3: print("6 is greater");print("six")
# Out:
# 6 is greater
# six

# %%
x=3
if x>1 : x=x*3
x
# Out:
# 9

# %%
# syntax

# if condition : true statement

# %%
x = 3
type(x)
# Out:
# int

# %%
type(float(input()))
# Out:
# 9
# float

# %%
# short hand if else

num = int(input("Enter number : \t"))
print("Even") if (num%2)==0 else print("Odd")
# Out:
# Enter number : 	3
# Odd

# %%
num = int(input("Enter number : \t"))
print("Positive") if (num>0) else print("Negative")
# Out:
# Enter number : 	9
# Positive

# %%
# syntax
# true statement  if condition else False statement

# %%
ML = True
salary = 12

if ML and salary>6:
    print("Go ahead")
# Out:
# Go ahead

# %%
week_off = True
wfh = True

if week_off or wfh: print('Good go ahead')
# Out:
# Good go ahead

# %%
raining =  False

if not raining: print("Go for purchase")
# Out:
# Go for purchase

# %%
file_closed = False

if not file_closed: print("Closing the file")
# Out:
# Closing the file

# %%
x = [1,2,3]

if x:
    print("x is not empty")
else:
    print('x is empty')
# Out:
# x is not empty

# %%
x = [1,2,3]

if not x:
    print("x is empty")
else:
    print('x is not empty')
# Out:
# x is not empty

# %%
good_pay = True
wfh = False
ML = True

if wfh and good_pay or ML:
    print("Go ahead")
# Out:
# Go ahead

# %%
x = 10

assert x == 10
print(x)
# Out:
# 10

# %%
x = 10

assert x == 100
print(x)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-39-dd1a8f648f44> in <module>
#       1 x = 10
#       2
# ----> 3 assert x == 100
#       4 print(x)
#
# AssertionError:

# %%
if True
  print("true")
# Out:
#   File "<ipython-input-42-3dd718ad0b4c>", line 1
#     if True
#            ^
# SyntaxError: invalid syntax

# %%
even = list(range(0,13,2))
i = int(input())
even[i]
# 0,2,4,6,8,10,12
# Out:
# 6
# 12

# %%
a = 3

if a>1:
    pass

# %%
# given 3 numbers find greatest by using if condition

# %%
# time  planner 
# cash spend planner
