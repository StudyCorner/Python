# %%
x = 100
def outer():
    x = 10
    def inner():
        nonlocal x
        x = x + 10
        print(x)
    inner()
    print(x)
    
    

outer()
print(x)
# Out:
# 20
# 100

# %%
light = "Sun light"  # global
def home():
  light = "Tube light"  # local variable
  print(light)

# %%
home()
# Out:
# Tube light

# %%
light
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e234044ad070> in <module>
# ----> 1 light
#
# NameError: name 'light' is not defined
