# %% [markdown]
# **Methods**

# %%
f = open('names.txt','w')
f.write('Tamil')
f.write('\nhema')
f.write('\nshyama')

names = ["\nHiranya","\nKarthik","\nMani"]
f.writelines(names)
f.close()

# %%
f = open('names.txt','r')
if f.readable():
  line1 = f.readline()
  print(line1)
  print("***************")
  lines = f.readlines()
  print(lines)
  f.seek(0)
  print("****************")
  print(f.read())
f.close()
# Out:
# Tamil
#
# ***************
# ['hema\n', 'shyama\n', 'Hiranya\n', 'Karthik\n', 'Mani']
# ****************
# Tamil
# hema
# shyama
# Hiranya
# Karthik
# Mani

# %%
f = open('new.txt','w')
f.write('hello !')
f.close()

# %%
f = open('new.txt')
print(f.read())
f.close()
# Out:
# hello !

# %%
f = open('new.txt','a')
f.write("\t Tamil , How are you ?")
f.close()

# %%
f = open('new.txt','r+')
print(f.read())
f.write("\nAre You clear with modules ?")
f.close()
# Out:
# hello !	 Tamil , How are you ?

# %%
f = open('quotes.txt','w+')
f.write("A Man who treats a man as a man he is a real man")
f.write("\nThe way i see it if you want rainbow,you gotta put up with the rain")
f.seek(0)
print(f.read())
f.close()
# Out:
# A Man who treats a man as a man he is a real man
# The way i see it if you want rainbow,you gotta put up with the rain

# %%
f = open('task.txt','a+')
f.seek(0)
lines = f.readlines()
for line in lines:
    print(line)
f.write("\n \t\t\t- Shyama")
f.close()


#1 . IEEE
#2 . Git Hub
#3 . Packages
#4 . Python Certification Exam
#5 . Ecommerce Django
